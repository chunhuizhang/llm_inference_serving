# %%
import os
os.environ['http_proxy'] = 'http://127.0.0.1:7890'
os.environ['https_proxy'] = 'http://127.0.0.1:7890'

# %% [markdown]
# ## 不完全量化

# %% [markdown]
# - load_in_8bit:
#     - embed_tokens 继续是 torch.float16
#     - 每个layer的内部（self attention）以及 mlp 部分是 int8
#     - 每个layer的output（layernorm）部分是 float16（如果 load 时传入了 `torch_dtype=torch.bfloat16`，则这部分为 torch.float16）
#     - 同理适用于 load_in_4bit
#
#     ```
#     model.embed_tokens.weight torch.float16 cuda:0
#     model.layers.0.self_attn.q_proj.weight torch.int8 cuda:0
#     model.layers.0.self_attn.k_proj.weight torch.int8 cuda:0
#     model.layers.0.self_attn.v_proj.weight torch.int8 cuda:0
#     model.layers.0.self_attn.o_proj.weight torch.int8 cuda:0
#     model.layers.0.mlp.gate_proj.weight torch.int8 cuda:0
#     model.layers.0.mlp.up_proj.weight torch.int8 cuda:0
#     model.layers.0.mlp.down_proj.weight torch.int8 cuda:0
#     model.layers.0.input_layernorm.weight torch.float16 cuda:0
#     model.layers.0.post_attention_layernorm.weight torch.float16 cuda:0
#     ```

# %%
import torch
from torch import nn
from transformers import BitsAndBytesConfig, AutoModelForCausalLM, AutoTokenizer
from transformers.optimization import AdamW

# %%
# del model
import gc         # garbage collect library
gc.collect()
torch.cuda.empty_cache()

# %%
model = AutoModelForCausalLM.from_pretrained("meta-llama/Meta-Llama-3-8B", 
                                             quantization_config=BitsAndBytesConfig(
                                                 load_in_8bit=True,
                                                 # load_in_4bit=True
                                             ), 
                                             torch_dtype=torch.bfloat16,
                                             device_map="auto")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# We've detected an older driver with an RTX 4000 series GPU. These drivers have issues with P2P. This can affect the multi-gpu inference when using accelerate device_map.Please make sure to update your driver to the latest version which resolves this.
# You are calling `save_pretrained` to a 4-bit converted model, but your `bitsandbytes` version doesn't support it. If you want to save 4-bit models, make sure to have `bitsandbytes>=0.41.3` installed.

# %%
for name, para in model.named_parameters():
    print(name, para.dtype, para.shape, para.device)
# Out:
# model.embed_tokens.weight torch.bfloat16 torch.Size([128256, 4096]) cuda:0
# model.layers.0.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.0.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.0.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.0.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.0.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.0.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.0.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.0.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.0.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.1.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.1.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.1.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.1.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.1.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.1.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.1.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.1.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.1.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.2.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.2.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.2.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.2.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.2.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.2.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.2.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.2.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.2.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.3.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.3.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.3.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.3.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.3.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.3.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.3.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.3.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.3.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.4.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.4.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.4.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.4.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.4.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.4.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.4.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.4.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.4.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.5.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.5.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.5.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.5.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.5.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.5.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.5.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.5.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.5.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.6.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.6.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.6.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.6.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.6.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.6.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.6.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.6.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.6.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.7.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.7.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.7.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:0
# model.layers.7.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:0
# model.layers.7.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.7.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.7.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:0
# model.layers.7.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.7.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:0
# model.layers.8.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.8.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.8.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.8.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.8.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.8.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.8.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.8.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.8.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.9.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.9.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.9.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.9.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.9.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.9.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.9.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.9.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.9.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.10.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.10.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.10.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.10.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.10.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.10.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.10.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.10.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.10.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.11.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.11.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.11.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.11.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.11.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.11.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.11.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.11.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.11.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.12.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.12.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.12.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.12.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.12.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.12.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.12.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.12.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.12.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.13.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.13.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.13.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.13.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.13.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.13.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.13.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.13.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.13.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.14.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.14.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.14.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.14.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.14.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.14.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.14.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.14.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.14.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.15.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.15.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.15.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.15.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.15.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.15.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.15.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.15.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.15.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.16.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.16.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.16.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.16.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.16.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.16.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.16.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.16.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.16.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.17.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.17.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.17.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.17.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.17.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.17.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.17.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.17.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.17.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.18.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.18.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.18.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.18.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.18.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.18.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.18.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.18.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.18.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.19.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.19.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.19.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.19.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.19.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.19.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.19.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.19.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.19.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.20.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.20.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.20.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.20.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.20.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.20.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.20.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.20.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.20.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.21.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.21.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.21.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.21.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.21.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.21.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.21.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.21.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.21.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.22.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.22.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.22.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.22.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.22.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.22.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.22.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.22.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.22.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.23.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.23.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.23.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.23.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.23.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.23.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.23.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.23.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.23.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.24.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.24.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.24.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.24.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.24.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.24.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.24.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.24.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.24.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.25.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.25.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.25.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.25.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.25.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.25.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.25.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.25.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.25.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.26.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.26.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.26.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.26.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.26.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.26.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.26.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.26.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.26.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.27.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.27.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.27.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.27.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.27.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.27.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.27.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.27.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.27.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.28.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.28.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.28.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.28.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.28.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.28.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.28.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.28.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.28.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.29.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.29.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.29.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.29.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.29.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.29.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.29.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.29.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.29.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.30.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.30.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.30.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.30.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.30.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.30.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.30.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.30.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.30.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.31.self_attn.q_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.31.self_attn.k_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.31.self_attn.v_proj.weight torch.uint8 torch.Size([2097152, 1]) cuda:1
# model.layers.31.self_attn.o_proj.weight torch.uint8 torch.Size([8388608, 1]) cuda:1
# model.layers.31.mlp.gate_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.31.mlp.up_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.31.mlp.down_proj.weight torch.uint8 torch.Size([29360128, 1]) cuda:1
# model.layers.31.input_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.layers.31.post_attention_layernorm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# model.norm.weight torch.bfloat16 torch.Size([4096]) cuda:1
# lm_head.weight torch.bfloat16 torch.Size([128256, 4096]) cuda:1

# %%
model
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
#     (norm): LlamaRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
# )

# %%
tokenizer = AutoTokenizer.from_pretrained('meta-llama/Meta-Llama-3-8B')
tokenizer.pad_token = tokenizer.eos_token
# 示例训练数据
texts = [
    "Hello, how are you?",
    "The quick brown fox jumps over the lazy dog."
]

# Tokenize数据
inputs = tokenizer(texts, return_tensors="pt", padding=True, truncation=True)
input_ids = inputs["input_ids"]
attention_mask = inputs["attention_mask"]

# 移动到GPU（如果可用）
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)
# model.to(device)

# 设置优化器和损失函数
optimizer = AdamW(model.parameters(), lr=5e-5)
loss_fn = nn.CrossEntropyLoss()

# 模型训练步骤
model.train()
outputs = model(input_ids, attention_mask=attention_mask, labels=input_ids)
loss = outputs.loss

# 反向传播
optimizer.zero_grad()
loss.backward()
optimizer.step()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# We detected that you are passing `past_key_values` as a tuple and this is deprecated and will be removed in v4.43. Please use an appropriate `Cache` class (https://huggingface.co/docs/transformers/v4.41.3/en/internal/generation_utils#transformers.Cache)
